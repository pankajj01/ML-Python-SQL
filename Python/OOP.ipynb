# %%
class  Atm:
    
    def __init__(self):
        
        self.pin=""
        self.balance=0
        
        self.menu()
        
    def menu(self):
        user_input=input("""
                    Hello how would you like to proceed?
                        1.Enter 1 to create pin
                        2.Enter 2 to deposit
                        3.Enter 3 to withdraw
                        4.Enter 4 to check balance
                        5.Enter 5 to exit     
""")
        if user_input=="1":
            self.create_pin()
        elif user_input=='2':
            self.deposit()
        elif user_input=='3':
            self.withdraw
        elif user_input=='4':
            self.check_balance
        elif user_input=='5':
            print("bye")
       
    def create_pin(self):
        self.pin=input("Enter your pin")
        print("Pin created successfully")
        
    def deposit(self):
        temp=input("Enter your pin")
        if temp==self.pin:
            amount=int(input("Enter amount to be deposited"))
            self.balance=amount+self.balance
        else:
            print("Wrong pin")
            
          
    def withdraw(self):
        temp1=input("Enter your pin")
        if temp1==self.pin:
            amount1=int(input("Enter the amount to withdraw"))
            if amount1<self.balance:
                self.balance=self.balance-amount
            else:
                print("Insufficient balance")
                
        else:
            print("Wrong pin")
       
    def check_balance(self):
        return self.balance

# %%
sbi=Atm()
# Out:
#                     Hello how would you like to proceed?
#                         1.Enter 1 to create pin
#                         2.Enter 2 to deposit
#                         3.Enter 3 to withdraw
#                         4.Enter 4 to check balance
#                         5.Enter 5 to exit
# 1
# Enter your pin1234
# Pin created successfully

# %%
sbi.deposit()
# Out:
# Enter your pin1234
# Enter amount to be deposited3532

# %%
sbi.check_balance()
# Out:
# 3532

# %%
class fraction:
    
    def __init__(self,num,denom):
        self.num=num
        self.denom=denom
        
    def __str__(self): ## This is magic function and will be triggered on print () function
        return"{}/{}".format(self.num,self.denom)
    
    def __add__(self,other): ## This is magic function and will be triggered on '+'
        temp_num=self.num*other.denom+self.denom*other.num   
        temp_denom=self.denom*other.denom
        
        return"{}/{}".format(temp_num,temp_denom)
    
    def __sub__(self,other): ## This is magic function and will be triggered on '-'
        temp_num=self.num*other.denom - self.denom*other.num   
        temp_denom=self.denom*other.denom
        
        return"{}/{}".format(temp_num,temp_denom)
    
    def __mul__(self,other): ## This is magic function and will be triggered on '*'
        temp_num=self.num*other.num  
        temp_denom=self.denom*other.denom
        
        return"{}/{}".format(temp_num,temp_denom)

# %%
f=fraction(5,6)

# %%
print(f)
# Out:
# 5/6

# %%
x=fraction(3,7)

# %%
print(x)
# Out:
# 3/7

# %%
print(x+f)
# Out:
# 53/42

# %%
print(f-x)
# Out:
# 17/42

# %% [markdown]
# ## Encapsulation

# %%
class  Atm:
    
    def __init__(self):
        
        self.__pin=""
        self.__balance=0 ## These two are variable (data) and if they are accesible from outside then they can be misused.
        
        self.menu()
        
    def menu(self):
        user_input=input("""
                    Hello how would you like to proceed?
                        1.Enter 1 to create pin
                        2.Enter 2 to deposit
                        3.Enter 3 to withdraw
                        4.Enter 4 to check balance
                        5.Enter 5 to exit     
""")
        if user_input=="1":
            self.create_pin()
        elif user_input=='2':
            self.deposit()
        elif user_input=='3':
            self.withdraw
        elif user_input=='4':
            self.check_balance
        elif user_input=='5':
            print("bye")
       
    def create_pin(self):
        self.__pin=input("Enter your pin")
        print("Pin created successfully")
        
    def deposit(self):
        temp=input("Enter your pin")
        if temp==self.__pin:
            amount=int(input("Enter amount to be deposited"))
            self.__balance=amount+self.__balance
        else:
            print("Wrong pin")
            
          
    def withdraw(self):
        temp1=input("Enter your pin")
        if temp1==self.__pin:
            amount1=int(input("Enter the amount to withdraw"))
            if amount1<self.__balance:
                self.__balance=self.__balance-amount
            else:
                print("Insufficient balance")
                
        else:
            print("Wrong pin")
       
    def check_balance(self):
        return self.__balance

# %%
hdfc=Atm()
# Out:
#                     Hello how would you like to proceed?
#                         1.Enter 1 to create pin
#                         2.Enter 2 to deposit
#                         3.Enter 3 to withdraw
#                         4.Enter 4 to check balance
#                         5.Enter 5 to exit
# 1
# Enter your pin1234
# Pin created successfully

# %% [markdown]
# ![Screenshot%202022-02-10%20at%2011.59.27%20PM.png](attachment:Screenshot%202022-02-10%20at%2011.59.27%20PM.png)

# %%
## When you try to encapsulate data in python we write double underscore before the variable as shown above.
## But internally that variable is stored as _Atm__pin and not __pin.

# %%
class customer:
    
    def __init__(self,name,gender):
        self.name=name
        self.gender=gender
       
    
def greet(customer):
    if customer.gender=='Male':
        print("Hello",customer.name,"Sir")
           
    else:
        print("Hello",customer.name,"Sir")
        cust2=customer("Pankaj","Male")
        
        return cust2
    
            
cust=customer("Lol","Male")
new_cust=greet(cust)
print(new_cust)

# %% [markdown]
# ![Screenshot%202022-02-11%20at%201.13.40%20PM.png](attachment:Screenshot%202022-02-11%20at%201.13.40%20PM.png)

# %%
## Once the values are changed they will changed in actual also without changing the address.
## Means the objects of a class are mutable.

# %% [markdown]
# ![Screenshot%202022-02-11%20at%201.38.19%20PM.png](attachment:Screenshot%202022-02-11%20at%201.38.19%20PM.png)

# %% [markdown]
#  ## Inheritance

# %% [markdown]
# ![Screenshot%202022-02-13%20at%207.22.43%20PM.png](attachment:Screenshot%202022-02-13%20at%207.22.43%20PM.png)

# %% [markdown]
# ## IRCTC Project

# %%
import requests
class IRCTC:
    
    def __init__(self):
        user_input=input("""How would you like to proceed?
        1.Enter 1 to check live train status.
        2.Enter 2 to check PNR.
        3.Enter 3 to check train schedule.""")
        
        if user_input=='1':
            print("live train status")
            
        elif user_input=='2':
            print("PNR status")
            
        elif user_input=='3':
            self.train_schedule()
            
       
    def train_schedule(self):
        train_no=input("Enter your train number")
        self.fetch_data(train_no)
        
       
    def fetch_data(self,train_no):
        data=requests.get("http://indianrailapi.com/api/v2/TrainSchedule/apikey/30c382602bfa67cfe2becb/TrainNumber/{}".format(train_no))
        data=data.json()
        
        print(data)
        
        print(data['Route'])
        
        for i in data['Route']:
            print(i['StationName'])

# %%
train=IRCTC()
