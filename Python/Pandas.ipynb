# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("match.csv")

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df[["team1","team2","toss_decision"]]
# Out:
#                            team1                        team2 toss_decision
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore         field
# 1                 Mumbai Indians       Rising Pune Supergiant         field
# 2                  Gujarat Lions        Kolkata Knight Riders         field
# 3         Rising Pune Supergiant              Kings XI Punjab         field
# 4    Royal Challengers Bangalore             Delhi Daredevils           bat
# ..                           ...                          ...           ...
# 631             Delhi Daredevils  Royal Challengers Bangalore         field
# 632                Gujarat Lions  Royal Challengers Bangalore         field
# 633          Sunrisers Hyderabad        Kolkata Knight Riders         field
# 634                Gujarat Lions          Sunrisers Hyderabad         field
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore           bat
#
# [636 rows x 3 columns]

# %%
df.iloc[1:3]
# Out:
#    id  season    city        date           team1                   team2  \
# 1   2    2017    Pune  2017-04-06  Mumbai Indians  Rising Pune Supergiant
# 2   3    2017  Rajkot  2017-04-07   Gujarat Lions   Kolkata Knight Riders
#
#               toss_winner toss_decision  result  dl_applied  \
# 1  Rising Pune Supergiant         field  normal           0
# 2   Kolkata Knight Riders         field  normal           0
#
#                    winner  win_by_runs  win_by_wickets player_of_match  \
# 1  Rising Pune Supergiant            0               7       SPD Smith
# 2   Kolkata Knight Riders            0              10         CA Lynn
#
#                                      venue         umpire1    umpire2  umpire3
# 1  Maharashtra Cricket Association Stadium  A Nand Kishore     S Ravi      NaN
# 2   Saurashtra Cricket Association Stadium     Nitin Menon  CK Nandan      NaN

# %%
df.iloc[1:3,4:8]
# Out:
#             team1                   team2             toss_winner  \
# 1  Mumbai Indians  Rising Pune Supergiant  Rising Pune Supergiant
# 2   Gujarat Lions   Kolkata Knight Riders   Kolkata Knight Riders
#
#   toss_decision
# 1         field
# 2         field

# %%
mask=df[df["city"]=="Hyderabad"]
mask.shape[0]
# Out:
# 49

# %%
mask1=df[(df["city"]=="Hyderabad") & (df["date"]>'2010-01-01')]
mask1.shape[0]
# Out:
# 42

# %%
df[df["city"]=="Hyderabad"]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 65    66    2008  Hyderabad  2008-04-22              Deccan Chargers
# 67    68    2008  Hyderabad  2008-04-24              Deccan Chargers
# 76    77    2008  Hyderabad  2008-05-01              Deccan Chargers
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# 91    92    2008  Hyderabad  2008-05-11        Kolkata Knight Riders
# ...

# %%
df["toss_decision"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %%
df["win_by_runs"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["win_by_wickets"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
 (df["team1"].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 82
# Chennai Super Kings            77
# Kings XI Punjab                77
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Delhi Daredevils               63
# Rajasthan Royals               54
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  14
# Rising Pune Supergiant          8
# Rising Pune Supergiants         7
# Kochi Tuskers Kerala            7
# Name: team1, dtype: int64

# %%
df.sort_values('city').head()
# Out:
#       id  season       city        date                        team1  \
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
#
#                      team2            toss_winner toss_decision  result  \
# 460       Rajasthan Royals       Rajasthan Royals         field  normal
# 471  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 470       Rajasthan Royals       Rajasthan Royals         field  normal
# 464       Delhi Daredevils    Chennai Super Kings           bat  normal
# 459        Kings XI Punjab    Chennai Super Kings           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %%
df.sort_values(['city','date'],ascending=[True,False]).head()
# Out:
#       id  season       city        date                        team1  \
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
#
#                      team2            toss_winner toss_decision  result  \
# 475  Kolkata Knight Riders       Rajasthan Royals           bat     tie
# 470       Rajasthan Royals       Rajasthan Royals         field  normal
# 471  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 464       Delhi Daredevils    Chennai Super Kings           bat  normal
# 459        Kings XI Punjab    Chennai Super Kings           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %%
 df.drop_duplicates(["city","toss_decision"])
# Out:
#       id  season            city        date                        team1  \
# 0      1    2017       Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017            Pune  2017-04-06               Mumbai Indians
# 2      3    2017          Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017          Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017       Bangalore  2017-04-08  Royal Challengers Bangalore
# 6      7    2017          Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017          Indore  2017-04-10  Royal Challengers Bangalore
# 10    11    2017         Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017       Bangalore  2017-04-14  Royal Challengers Bangalore
# 14    15    2017           Delhi  2017-04-15             Delhi Daredevils
# 20    21    2017       Hyderabad  2017-04-19          Sunrisers Hyderabad
# 31    32    2017      Chandigarh  2017-04-28          Sunrisers Hyderabad
# ...

# %%
 df.drop_duplicates(["season"],keep='last')[["season","winner"]]
# Out:
#      season                 winner
# 58     2017         Mumbai Indians
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad

# %%
cities=df.groupby(["city"])

# %%
cities

# %%
cities.size()
# Out:
# city
# Abu Dhabi          7
# Ahmedabad         12
# Bangalore         66
# Bloemfontein       2
# Cape Town          7
# Centurion         12
# Chandigarh        46
# Chennai           48
# Cuttack            7
# Delhi             60
# Dharamsala         9
# Durban            15
# East London        3
# Hyderabad         49
# Indore             5
# Jaipur            33
# Johannesburg       8
# Kanpur             4
# Kimberley          3
# Kochi              5
# Kolkata           61
# Mumbai            85
# Nagpur             3
# Port Elizabeth     7
# Pune              32
# Raipur             6
# Rajkot            10
# Ranchi             7
# Sharjah            6
# Visakhapatnam     11
# dtype: int64

# %%
d=pd.read_csv("ipl.csv")

# %%
d.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
mask=d[d["batsman_runs"]==4]
mask
# Out:
#         match_id  inning                 batting_team  \
# 2              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 30             1       1          Sunrisers Hyderabad
# 32             1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150403       636       2  Royal Challengers Bangalore
# 150407       636       2  Royal Challengers Bangalore
# 150418       636       2  Royal Challengers Bangalore
# 150447       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman  \
# 2       Royal Challengers Bangalore     1     3      DA Warner
# 8       Royal Challengers Bangalore     2     2      DA Warner
# 13      Royal Challengers Bangalore     2     7   MC Henriques
# ...

# %%
fours=mask.groupby("batsman")

# %%
fours["batsman_runs"].count().sort_values(ascending=False).head()
# Out:
# batsman
# G Gambhir    484
# SK Raina     402
# DA Warner    401
# S Dhawan     401
# V Kohli      384
# Name: batsman_runs, dtype: int64

# %%
team=d.groupby(["batsman","bowling_team"])

# %%
team["total_runs"].sum().sort_values(ascending=False).head()
# Out:
# batsman    bowling_team
# CH Gayle   Kings XI Punjab          850
# SK Raina   Mumbai Indians           750
# RG Sharma  Kolkata Knight Riders    741
# V Kohli    Chennai Super Kings      732
# SK Raina   Kolkata Knight Riders    730
# Name: total_runs, dtype: int64

# %%
d.groupby(["batsman","bowling_team"])["total_runs"].mean().sort_values(ascending=False).head()
# Out:
# batsman          bowling_team
# Rashid Khan      Kings XI Punjab           6.000000
# CH Morris        Rising Pune Supergiant    4.222222
# J Syed Mohammad  Deccan Chargers           4.000000
# Z Khan           Delhi Daredevils          4.000000
# DT Patil         Kings XI Punjab           4.000000
# Name: total_runs, dtype: float64

# %%
# merge

m=df.merge(d,left_on='id',right_on='match_id')

# %%
# pivot table

m.pivot_table(index='season',columns='city',values='total_runs',aggfunc='mean')
# Out:
# city    Abu Dhabi  Ahmedabad  Bangalore  Bloemfontein  Cape Town  Centurion  \
# season
# 2008          NaN        NaN   1.248166           NaN        NaN        NaN
# 2009          NaN        NaN        NaN         1.058   1.167641   1.274599
# 2010          NaN   1.292063   1.350835           NaN        NaN        NaN
# 2011          NaN        NaN   1.228934           NaN        NaN        NaN
# 2012          NaN        NaN   1.344162           NaN        NaN        NaN
# 2013          NaN        NaN   1.361312           NaN        NaN        NaN
# 2014     1.190271   1.241968   1.443992           NaN        NaN        NaN
# 2015          NaN   1.375000   1.494030           NaN        NaN        NaN
# 2016          NaN        NaN   1.520261           NaN        NaN        NaN
# 2017          NaN        NaN   1.194585           NaN        NaN        NaN
#
# city    Chandigarh   Chennai   Cuttack     Delhi  ...   Kolkata    Mumbai  \
# ...

# %%
#correlation

df.corr()
# Out:
#                       id    season  dl_applied  win_by_runs  win_by_wickets  \
# id              1.000000  0.471087    0.024281    -0.010263       -0.015510
# season          0.471087  1.000000    0.004170    -0.016815       -0.000708
# dl_applied      0.024281  0.004170    1.000000    -0.010893       -0.011640
# win_by_runs    -0.010263 -0.016815   -0.010893     1.000000       -0.565181
# win_by_wickets -0.015510 -0.000708   -0.011640    -0.565181        1.000000
# umpire3              NaN       NaN         NaN          NaN             NaN
#
#                 umpire3
# id                  NaN
# season              NaN
# dl_applied          NaN
# win_by_runs         NaN
# win_by_wickets      NaN
# umpire3             NaN

# %%
df.rename(columns={"id":"lol"},inplace=True)

# %%
df
# Out:
#      lol  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df["umpire3"].replace(np.NaN,"?")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-122-b6f5d363c59d> in <module>
# ----> 1 df["umpire3"].replace(np.NaN,"?")
#
# NameError: name 'np' is not defined
