# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("student.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df=pd.read_csv("student.csv")
#       2 df
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
result_df=df[df["math score"]>=70]

# %%
result_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 984  female        group C            some high school      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
options=["group A","group B"]

r=df[df["race/ethnicity"].isin(options)]

# %%
r
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 985    male        group A                 high school      standard
# 988  female        group A            some high school  free/reduced
# 991  female        group B            some high school      standard
# 994    male        group A                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
a=df[~df["race/ethnicity"].isin(options)]
a
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 4      male        group C                some college      standard
# 8      male        group D                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
b = df[(df["math score"]==72) & (df["race/ethnicity"].isin(options))]
b
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 126    male        group B            some high school      standard
# 170    male        group A                 high school      standard
# 459    male        group B                 high school      standard
# 467    male        group A                 high school  free/reduced
# 642  female        group B            some high school  free/reduced
# 778  female        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 126                    none          72             68             67
# 170               completed          72             73             74
# 459               completed          72             65             68
# ...

# %%
d=df.loc[1:,["gender","lunch"]]
d
# Out:
#      gender         lunch
# 1    female      standard
# 2    female      standard
# 3      male  free/reduced
# 4      male      standard
# 5    female      standard
# ..      ...           ...
# 995  female      standard
# 996    male  free/reduced
# 997  female  free/reduced
# 998  female      standard
# 999  female  free/reduced
#
# [999 rows x 2 columns]

# %%
e=df.iloc[1:3,1:3]
e
# Out:
#   race/ethnicity parental level of education
# 1        group C                some college
# 2        group B             master's degree

# %% [markdown]
# # Difference between loc and iloc

# %% [markdown]
# ![Screenshot%202021-10-30%20at%2010.07.58%20AM.png](attachment:Screenshot%202021-10-30%20at%2010.07.58%20AM.png)

# %%
df["Good maths"]=df["math score"].apply(lambda x:"Good" if(x>=80)else "bad")

# %%
df["Good maths"].value_counts()
# Out:
# bad     807
# Good    193
# Name: Good maths, dtype: int64

# %%
df1=df[df["parental level of education"].str.contains("asso")]

# %%
df1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 5    female        group B          associate's degree      standard
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 19   female        group C          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 968  female        group E          associate's degree      standard
# 977    male        group C          associate's degree      standard
# 979  female        group C          associate's degree      standard
# 986  female        group C          associate's degree      standard
# 992  female        group D          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...
