# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("heart.csv")

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %% [markdown]
# ## Removing outliers

# %%
df[df['Cholesterol']>(df['Cholesterol'].mean()+3*df.Cholesterol.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 76    32   M           ASY        118          529          0     Normal
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 76     130              N      0.0     Flat             1
# 149    125              Y      1.0     Flat             1
# 616    160              N      1.6     Flat             0

# %%
df1=df[df['Cholesterol']<=(df['Cholesterol'].mean()+3*df.Cholesterol.std())]

# %%
df1
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df1.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  915.000000  915.000000   915.000000  915.000000  915.000000
# mean    53.519126  132.433880   197.597814    0.232787  136.804372
# std      9.410666   18.529259   107.511650    0.422839   25.486556
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.000000    0.000000  120.000000
# 50%     54.000000  130.000000   222.000000    0.000000  138.000000
# 75%     60.000000  140.000000   266.500000    0.000000  156.000000
# max     77.000000  200.000000   518.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  915.000000    915.000000
# mean     0.887432      0.553005
# std      1.067649      0.497454
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df[df['RestingBP']>(df['RestingBP'].mean()+3*df.RestingBP.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 109   39   M           ATA        190          241          0     Normal
# 241   54   M           ASY        200          198          0     Normal
# 365   64   F           ASY        200            0          0     Normal
# 399   61   M           NAP        200            0          1         ST
# 592   61   M           ASY        190          287          1        LVH
# 732   56   F           ASY        200          288          1        LVH
# 759   54   M           ATA        192          283          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 109    106              N      0.0       Up             0
# 241    142              Y      2.0     Flat             1
# 365    140              Y      1.0     Flat             1
# 399     70              N      0.0     Flat             1
# 592    150              Y      2.0     Down             1
# ...

# %%
df1=df1[df1['RestingBP']<=(df1['RestingBP'].mean()+3*df1.RestingBP.std())]

# %%
df1.shape
# Out:
# (908, 12)

# %%
df1=df1[df1['Oldpeak']<=(df1['Oldpeak'].mean()+3*df1.Oldpeak.std())]

# %%
df1.shape
# Out:
# (902, 12)

# %% [markdown]
# ## Label encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label=LabelEncoder()

# %%
df1['RestingECG']=label.fit_transform(df1.RestingECG)
df1['ExerciseAngina']=label.fit_transform(df1.ExerciseAngina)
df1['ST_Slope']=label.fit_transform(df1.ST_Slope)

# %% [markdown]
# ## Onehot Encoding

# %%
df1=pd.get_dummies(df1,drop_first=True)
df1
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# 0     40        140          289          0           1    172
# 1     49        160          180          0           1    156
# 2     37        130          283          0           2     98
# 3     48        138          214          0           1    108
# 4     54        150          195          0           1    122
# ..   ...        ...          ...        ...         ...    ...
# 913   45        110          264          0           1    132
# 914   68        144          193          1           1    141
# 915   57        130          131          0           1    115
# 916   57        130          236          0           0    174
# 917   38        138          175          0           1    173
#
#      ExerciseAngina  Oldpeak  ST_Slope  HeartDisease  Sex_M  \
# 0                 0      0.0         2             0      1
# 1                 0      1.0         1             1      0
# ...

# %%
X=df1.drop("HeartDisease",axis=1)

# %%
y=df1.HeartDisease

# %% [markdown]
# ## Scaling the input data

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

X_scaled=scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-1.42896269,  0.46089071,  0.85238015, ...,  2.06757196,
#         -0.53547478, -0.22914788],
#        [-0.47545956,  1.5925728 , -0.16132855, ..., -0.4836591 ,
#          1.86750159, -0.22914788],
#        [-1.74679706, -0.10495034,  0.79657967, ...,  2.06757196,
#         -0.53547478, -0.22914788],
#        ...,
#        [ 0.37209878, -0.10495034, -0.61703246, ..., -0.4836591 ,
#         -0.53547478, -0.22914788],
#        [ 0.37209878, -0.10495034,  0.35947592, ...,  2.06757196,
#         -0.53547478, -0.22914788],
#        [-1.64085227,  0.3477225 , -0.20782894, ..., -0.4836591 ,
#          1.86750159, -0.22914788]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=20)

# %% [markdown]
# ## Training standalone models and Bagging

# %%
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
svc=SVC()

x=cross_val_score(svc,X_scaled,y,cv=5)
x.mean()
# Out:
# 0.8203499079189687

# %%
dt=DecisionTreeClassifier()

x=cross_val_score(dt,X_scaled,y,cv=5)
x.mean()
# Out:
# 0.7326764886433395

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bag_model = BaggingClassifier(base_estimator=svc, n_estimators=100, max_samples=0.8, random_state=0)
scores = cross_val_score(bag_model, X_scaled, y, cv=5)
scores.mean()
# Out:
# 0.8214610190300797

# %%
bag_model = BaggingClassifier(base_estimator=dt, n_estimators=100, max_samples=0.8, random_state=0)
scores = cross_val_score(bag_model, X_scaled, y, cv=5)
scores.mean()
# Out:
# 0.8059054634745243

# %%
parameters = {
    'n_estimators': [50,100,500], 
    'max_samples': [0.1,0.4,0.7,1.0],
    'bootstrap' : [True,False],
    'max_features' : [0.1,0.4,0.7,1.0]
    }

# %%
search=GridSearchCV(bag_model,parameters,cv=5)

# %%
search.fit(X_scaled,y)
# Out:
# GridSearchCV(cv=5,
#              estimator=BaggingClassifier(base_estimator=DecisionTreeClassifier(),
#                                          max_samples=0.8, n_estimators=100,
#                                          random_state=0),
#              param_grid={'bootstrap': [True, False],
#                          'max_features': [0.1, 0.4, 0.7, 1.0],
#                          'max_samples': [0.1, 0.4, 0.7, 1.0],
#                          'n_estimators': [50, 100, 500]})

# %%
search.best_params_
# Out:
# {'bootstrap': True,
#  'max_features': 0.4,
#  'max_samples': 1.0,
#  'n_estimators': 100}

# %%
search.best_score_
# Out:
# 0.8436034376918355
