# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression
import math

# %%
df=pd.read_csv("test_scores.csv")

# %%
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
def predict_using_sklearn():
    df=pd.read_csv("test_scores.csv")
    model=LinearRegression()
    model.fit(df[['math']],df.cs)
    return model.coef_,model.intercept_

# %%
def gradient_descent(x,y):
    b_curr=m_curr=0
    iterations=1000
    learning_rate=0.01
    n=len(x)
    cost_previous = 0
    
    for i in range(iterations):
        y_p=m_curr*x+b_curr
        cost=sum([value**2 for value in (y-y_p)])
        md=-2*sum(x*(y-y_p))
        bd=-2*sum(y-y_p)
        m_curr=m_curr-learning_rate*md
        b_curr=b_curr-learning_rate*bd
        
        print ("m {}, b {}, cost {}, iteration {}".format(m_curr,b_curr,cost, i))
        
    return m_curr,b_curr

# %%
x=np.array(df.math)
y=np.array(df.cs)

m,b=gradient_descent(x,y)
print("The intercept and slope using GD is",m,b)
# Out:
# m 989.1800000000001, b 13.98, cost 51991, iteration 0
# m -934764.0367999999, b -13190.280800000002, cost 46241766493.370415, iteration 1
# m 884277037.3369279, b 12477909.287007999, cost 4.138149214106178e+16, iteration 2
# m -836515925792.1608, b -11803958877.411749, cost 3.703206069874236e+22, iteration 3
# m 791334463505817.0, b 11166409601495.32, cost 3.3139779370946625e+28, iteration 4
# m -7.485933188160768e+17, b -1.0563295304756504e+16, cost 2.965659906666541e+34, iteration 5
# m 7.081606865615168e+20, b 9.992756103138982e+18, cost 2.6539520929098356e+40, iteration 6
# m -6.699118805714207e+23, b -9.453032567579353e+21, cost 2.3750065527161135e+46, iteration 7
# m 6.337289491595525e+26, b 8.942460298380116e+24, cost 2.1253797838000818e+52, iteration 8
# m -5.995003113846912e+29, b -8.459464792532917e+27, cost 1.9019902156564828e+58, iteration 9
# m 5.671204129572692e+32, b 8.002556588265448e+30, cost 1.7020801684605053e+64, iteration 10
# ...

# %%
m_sk,b_sk=predict_using_sklearn()
print("The intercept and slope using sklearn is",m_sk,b_sk)
# Out:
# The intercept and slope using sklearn is [1.01773624] 1.9152193111569176

# %%
data = pd.read_csv('test_scores.csv')
X = data.iloc[:, 1]
Y = data.iloc[:, 2]
plt.scatter(X, Y)
plt.show()

# %%
X
# Out:
# 0    92
# 1    56
# 2    88
# 3    70
# 4    80
# 5    49
# 6    65
# 7    35
# 8    66
# 9    67
# Name: math, dtype: int64

# %%
m = 0
c = 0

L = 0.001  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    
print (m, c)
# Out:
# nan nan

# %%
df1=pd.read_csv("test_scores.csv")
model=LinearRegression()
model.fit(df[['math']],df.cs)
print (model.coef_,model.intercept_)
# Out:
# [1.01773624] 1.9152193111569176
